# %%
# Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#Reading CSV
Population = pd.read_csv("../Dataset/Population_by_Country.csv", encoding="ISO-8859-1")
Population.head()
# Out:
#        Country       1960       1961       1962       1963       1964  \
# 0        Aruba    54211.0    55438.0    56225.0    56695.0    57032.0
# 1  Afghanistan  8996973.0  9169410.0  9351441.0  9543205.0  9744781.0
# 2       Angola  5454933.0  5531472.0  5608539.0  5679458.0  5735044.0
# 3      Albania  1608800.0  1659800.0  1711319.0  1762621.0  1814135.0
# 4      Andorra    13411.0    14375.0    15370.0    16412.0    17469.0
#
#         1965        1966        1967        1968     ...            2009  \
# 0    57360.0     57715.0     58055.0     58386.0     ...        101455.0
# 1  9956320.0  10174836.0  10399926.0  10637063.0     ...      28394813.0
# 2  5770570.0   5781214.0   5774243.0   5771652.0     ...      22514281.0
# 3  1864791.0   1914573.0   1965598.0   2022272.0     ...       2927519.0
# 4    18549.0     19647.0     20758.0     21890.0     ...         84463.0
#
#          2010        2011        2012        2013        2014        2015  \
# ...

# %%
#Indexing Country
Population.set_index('Country', inplace=True)
Population.head()
# Out:
#                   1960       1961       1962       1963       1964       1965  \
# Country
# Aruba          54211.0    55438.0    56225.0    56695.0    57032.0    57360.0
# Afghanistan  8996973.0  9169410.0  9351441.0  9543205.0  9744781.0  9956320.0
# Angola       5454933.0  5531472.0  5608539.0  5679458.0  5735044.0  5770570.0
# Albania      1608800.0  1659800.0  1711319.0  1762621.0  1814135.0  1864791.0
# Andorra        13411.0    14375.0    15370.0    16412.0    17469.0    18549.0
#
#                    1966        1967        1968        1969     ...      \
# Country                                                         ...
# Aruba           57715.0     58055.0     58386.0     58726.0     ...
# Afghanistan  10174836.0  10399926.0  10637063.0  10893776.0     ...
# Angola        5781214.0   5774243.0   5771652.0   5803254.0     ...
# Albania       1914573.0   1965598.0   2022272.0   2081695.0     ...
# Andorra         19647.0     20758.0     21890.0     23058.0     ...
#
# ...

# %%
#Counting Rows and Columns
Population.columns
# Out:
# Index(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018'],
#       dtype='object')

# %%
# Dropping columns, in order to analyse from 2008 to 2018
Population.drop(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989','1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007'], axis=1, inplace=True)
Population.head()
# Out:
#                    2008        2009        2010        2011        2012  \
# Country
# Aruba          101358.0    101455.0    101669.0    102046.0    102560.0
# Afghanistan  27722276.0  28394813.0  29185507.0  30117413.0  31161376.0
# Angola       21695634.0  22514281.0  23356246.0  24220661.0  25107931.0
# Albania       2947314.0   2927519.0   2913021.0   2905195.0   2900401.0
# Andorra         83862.0     84463.0     84449.0     83747.0     82427.0
#
#                    2013        2014        2015        2016        2017  \
# Country
# Aruba          103159.0    103774.0    104341.0    104872.0    105366.0
# Afghanistan  32269589.0  33370794.0  34413603.0  35383128.0  36296400.0
# Angola       26015780.0  26941779.0  27884381.0  28842484.0  29816748.0
# Albania       2895092.0   2889104.0   2880703.0   2876101.0   2873457.0
# Andorra         80774.0     79213.0     78011.0     77297.0     77001.0
#
#                    2018
# Country
# Aruba          105845.0
# ...

# %%
# Filter Data for Canada, China, Philippines and India
Pop_Analysis= Population.loc[["Canada", "China", "India", "Philippines"], :]
Pop_Analysis.head()
# Out:
#                      2008          2009          2010          2011  \
# Country
# Canada       3.324712e+07  3.362890e+07  3.400489e+07  3.433933e+07
# China        1.324655e+09  1.331260e+09  1.337705e+09  1.344130e+09
# India        1.200670e+09  1.217726e+09  1.234281e+09  1.250289e+09
# Philippines  9.090196e+07  9.241416e+07  9.396678e+07  9.557005e+07
#
#                      2012          2013          2014          2015  \
# Country
# Canada       3.471422e+07  3.508295e+07  3.543744e+07  3.570291e+07
# China        1.350695e+09  1.357380e+09  1.364270e+09  1.371220e+09
# India        1.265783e+09  1.280846e+09  1.295604e+09  1.310152e+09
# Philippines  9.721264e+07  9.887155e+07  1.005131e+08  1.021132e+08
#
#                      2016          2017          2018
# Country
# Canada       3.610949e+07  3.654027e+07  3.705886e+07
# China        1.378665e+09  1.386395e+09  1.392730e+09
# India        1.324510e+09  1.338659e+09  1.352617e+09
# ...

# %%
#Transpose the Data to depict the Graph
Pop_df = Pop_Analysis.T/1000000
Pop_df.head(11)
# Out:
# Country     Canada     China        India  Philippines
# 2008     33.247118  1324.655  1200.669765    90.901965
# 2009     33.628895  1331.260  1217.726215    92.414158
# 2010     34.004889  1337.705  1234.281170    93.966780
# 2011     34.339328  1344.130  1250.288729    95.570047
# 2012     34.714222  1350.695  1265.782790    97.212638
# 2013     35.082954  1357.380  1280.846129    98.871552
# 2014     35.437435  1364.270  1295.604184   100.513138
# 2015     35.702908  1371.220  1310.152403   102.113212
# 2016     36.109487  1378.665  1324.509589   103.663927
# 2017     36.540268  1386.395  1338.658835   105.173264
# 2018     37.058856  1392.730  1352.617328   106.651922

# %%
Pop_df.describe()
# Out:
# Country     Canada        China        India  Philippines
# count    11.000000    11.000000    11.000000    11.000000
# mean     35.078760  1358.100455  1279.194285    98.822964
# std       1.221772    22.668016    50.187531     5.284986
# min      33.247118  1324.655000  1200.669765    90.901965
# 25%      34.172109  1340.917500  1242.284950    94.768414
# 50%      35.082954  1357.380000  1280.846129    98.871552
# 75%      35.906198  1374.942500  1317.330996   102.888570
# max      37.058856  1392.730000  1352.617328   106.651922

# %%
# Plot the line
plt.figure(figsize=(10,5))
plt.title("Population Growth from 1990 to 2018")
plt.plot(Pop_df)
plt.xlabel('Years')
plt.ylabel('Total Population in Million')
plt.legend(Pop_df, loc = 'best')
plt.show()

# %%
# Analysis
# Canada's Population growth has been constant and was recorded to be the lowest among the top 3 immigrant countries. Still Canada is disperesly populated having more space for immigrants  
#fig  = plt.figure()
#axes_countries = fig.add_axes([0,0,1,1])
#axes_canada = fig.add_axes([0.5,0.2,0.4,0.4])
#axes_countries.plot(Pop_df)
#axes_canada.plot(Pop_df)
