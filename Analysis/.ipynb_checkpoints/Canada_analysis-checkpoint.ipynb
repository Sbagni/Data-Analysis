# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df_canada = pd.read_csv("../Dataset/IRCC_FF_TR_2017_05_CSV.csv", encoding="ISO-8859-1")
df_canada
# Out:
#                                  Unnamed: 0  \
# 0                               Philippines
# 1                                     India
# 2                                 Guatemala
# 3                                    Mexico
# 4                        Korea, Republic of
# 5                  United States of America
# 6                                    France
# 7   United Kingdom and Overseas Territories
# 8                                  Thailand
# 9               China, People's Republic of
# 10                                  Jamaica
# 11                                    Italy
# 12                                    Japan
# 13                                  Ukraine
# 14                                   Brazil
# 15                                 Portugal
# 16                                   Israel
# 17                                   Poland
# 18                                  Germany
# 19                     Ireland, Republic of
# ...

# %%
#clean
# del df_canada["Unnamed: 0"]

# %%
df_canada = df_canada.rename(columns={'Unnamed: 1': "Country"})
df_canada
value = 0
for x in range(2008,2017):
 value = value + df_canada[x]
df_canada["Mean"] = x
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2008
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-f55af974a274> in <module>
#       3 value = 0
# ...

# %%
df_canada.head()
# Out:
#                 Country   2008   2009   2010   2011   2012   2013   2014  \
# 0           Philippines  46972  51292  44840  41762  40744  43689  39925
# 1                  Inde   8332   8341   7519   5974   6698   8033   6251
# 2             Guatemala   1113   1239   1471   1520   1998   2488   2725
# 3               Mexique   4792   4449   2787   4080   3003   4245   3879
# 4  Corée, République de   3469   3694   2720   2204   2485   3334   2561
#
#     2015   2016   2017   Mean
# 0  23642  14718  11901  98264
# 1   3335   3288   5749  16673
# 2   3140   4278   5603   2352
# 3   2493   7961   2574   9241
# 4   1412   1415   2158   7163
